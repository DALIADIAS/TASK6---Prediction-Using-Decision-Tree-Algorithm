# %% [markdown]
# <a href="https://colab.research.google.com/github/DALIADIAS/TASK6---Prediction-Using-Decision-Tree-Algorithm/blob/main/TASK_6_DATA_SCIENCE_AND_BUSINESS_ANALYTICS_INTERNSHIP_(GRIPJANUARY2022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***THE SPARKS FOUNDATION - DATA SCIENCE AND BUSINESS ANALYTICS INTERNSHIP (GRIPJANUARY2022)***

# %% [markdown]
# ***TASK 6-Prediction using Decision Tree Algorithm***

# %% [markdown]
# ***In this task we will Create the Decision Tree classifier and visualize it graphically.The purpose of this is if we feed any new data to this classifier, it would be able to predict the right class accordingly.***

# %% [markdown]
# ***AUTHOR : DALIA ROBIN DIAS***

# %% [markdown]
# ***Importing Libraries and loading iris dataset***

# %%
# Importing the required Libraries

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
import sklearn.metrics as sm

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import pydot
from IPython.display import Image

# %% [markdown]
# ***Loading the Dataset***

# %%
# Loading Dataset
iris = load_iris()
X=iris.data[:,:] 
y=iris.target

# %% [markdown]
# ***Exploratory Data Analysis***

# %%
#Input data 

data=pd.DataFrame(iris['data'],columns=["Petal length","Petal Width","Sepal Length","Sepal Width"])
data['Species']=iris['target']
data['Species']=data['Species'].apply(lambda x: iris['target_names'][x])

data.head()
# Out:
#    Petal length  Petal Width  Sepal Length  Sepal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.describe()
# Out:
#        Petal length  Petal Width  Sepal Length  Sepal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ***Data Visualization comparing various features***

# %%
# Input data Visualization
sns.pairplot(data)

# %%
# Scatter plot of data based on Sepal Length and Width features
sns.FacetGrid(data,hue='Species').map(plt.scatter,'Sepal Length','Sepal Width').add_legend()
plt.show()

# Scatter plot of data based on Petal Length and Width features
sns.FacetGrid(data,hue='Species').map(plt.scatter,'Petal length','Petal Width').add_legend()
plt.show()

# %% [markdown]
# ***Decision Tree Model Training***

# %%
# Model Training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42) 
tree_classifier = DecisionTreeClassifier()
tree_classifier.fit(X_train,y_train)
print("Training Complete.")
y_pred = tree_classifier.predict(X_test)
# Out:
# Training Complete.

# %% [markdown]
# ***Comparing the actual and predicted flower classification***

# %%
df= pd.DataFrame({'Actual': y_test, 'Predicted': y_pred}) 
df
# Out:
#     Actual  Predicted
# 0        1          1
# 1        0          0
# 2        2          2
# 3        1          1
# 4        1          1
# 5        0          0
# 6        1          1
# 7        2          2
# 8        1          1
# 9        1          1
# 10       2          2
# 11       0          0
# 12       0          0
# 13       0          0
# 14       0          0
# 15       1          1
# 16       2          2
# 17       1          1
# 18       1          1
# 19       2          2
# 20       0          0
# 21       2          2
# 22       0          0
# 23       2          2
# 24       2          2
# 25       2          2
# 26       2          2
# 27       2          2
# 28       0          0
# 29       0          0
# 30       0          0
# 31       0          0
# 32       1          1
# 33       0          0
# 34       0          0
# 35       2          2
# 36       1          1
# 37       0          0
# 38       0          0
# 39       0          0
# 40       2          2
# 41       1          1
# 42       1          1
# 43       0          0
# 44       0          0
# 45       1          1
# 46       2          1
# 47       2          2
# 48       1          1
# 49       2          2

# %% [markdown]
# ***Visualizing the Trained Model***

# %%
#Visualizing the trained Decision Tree Classifier taking all 4 features in consideration

export_graphviz(
        tree_classifier,
        out_file="img\desision_tree.dot",
        feature_names=iris.feature_names[:],
        class_names=iris.target_names,
        rounded=True,
        filled=True
)

(graph,) = pydot.graph_from_dot_file('img\desision_tree.dot')
graph.write_png('img\desision_tree.png')

Image(filename='img\desision_tree.png')

# %% [markdown]
# ***OR***

# %% [markdown]
# ***Import the DecisionTreeClassifier and fit the model***

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)


print('Decision Tree Classifer Created Successfully')
# Out:
# Decision Tree Classifer Created Successfully

# %%
import matplotlib.pyplot as plt
from sklearn import tree


a=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
b=['setosa','versicolor','virginica']

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (4,4), dpi = 300)

tree.plot_tree(dtree, feature_names = a, class_names = b, filled = True);

# %% [markdown]
# ***Predicting the class output for some random values of petal and sepal length and width***

# %%
print("Class Names = ",iris.target_names)

# Estimating class probabilities
print()
print("Estimating Class Probabilities for flower whose petals length width are 4.7cm and 3.2cm and sepal length and width are 1.3cm and 0.2cm. ")
print()
print('Output = ',tree_classifier.predict([[4.7, 3.2, 1.3, 0.2]]))
print()
print("Our model predicts the class as 0, that is, setosa.")
# Out:
# Class Names =  ['setosa' 'versicolor' 'virginica']
#
# Estimating Class Probabilities for flower whose petals length width are 4.7cm and 3.2cm and sepal length and width are 1.3cm and 0.2cm.
#
# Output =  [0]
#
# Our model predicts the class as 0, that is, setosa.

# %% [markdown]
# ***Calculating the Model Accuracy***

# %%
# Model Accuracy
print("Accuracy:",sm.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.98

# %% [markdown]
# ***Conclusion: I was successfully able to carry-out the prediction using Decision Tree Algorithm and evaluate the model's accuracy.***

# %% [markdown]
# ***Thank You***
